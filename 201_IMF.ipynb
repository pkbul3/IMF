# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('201_table1-oct2021weo.XLSX', header=6)
df = df.iloc[:, 0:4]
col_name = ['Country', '2020', '2021', '2022']
df.columns = col_name
df = df.dropna()
df['Country'] = df.Country.str[0:15]
df = df.set_index('Country')
df = df.sort_values(by=['2022'])
#df.head(5)
df.plot.bar(stacked=True)

# %% [markdown]
# ## India's 'post-pandemic' economic growth compared to other countries.
# IMF reported these records 20th april 2022.

# %%
print("making some changes for git tutotial, 3rd change")
# Out:
# making some changes for git tutotial, 3rd change
